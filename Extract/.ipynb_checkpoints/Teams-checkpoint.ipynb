# %%
import pandas as pd
from basketball_reference_scraper.teams import get_roster

# %%
f=open("Team_Name.txt","r")
lines=f.readlines()
result=[]
for x in lines:
    result.append(x.split(':')[1])
f.close()

# %%
clean_teamlist = list(map(lambda each:each.strip("\n"), result))
clean_teamlist = [x.strip(' ') for x in clean_teamlist]
clean_teamlist
# Out:
# ['ATL',
#  'SLH',
#  'MIL',
#  'TCB',
#  'BOS',
#  'BRK',
#  'NJN',
#  'CHI',
#  'CHH',
#  'CHO',
#  'CHA',
#  'CLE',
#  'DAL',
#  'DEN',
#  'DET',
#  'FWP',
#  'GSW',
#  'SFW',
#  'PHI',
#  'HOU',
#  'IND',
#  'LAC',
#  'SDC',
#  'BUF',
#  'LAL',
#  'MIN',
#  'MEM',
#  'VAN',
#  'MIA',
#  'MIL',
#  'MIN',
#  'NOP',
#  'NOK',
#  'NOH',
#  'NYK',
#  'OKC',
#  'SEA',
#  'ORL',
#  'PHI',
#  'SYR',
#  'PHO',
#  'POR',
#  'SAC',
#  'KCK',
#  'KCK',
#  'CIN',
#  'ROR',
#  'SAS',
#  'TOR',
#  'UTA',
#  'NOJ',
#  'WAS',
#  'WAS',
#  'CAP',
#  'BAL',
#  'CHI',
#  'CHI',
#  'AND',
#  'CHI',
#  'IND',
#  'SRS',
#  'SLB',
#  'WAS',
#  'WAT']

# %%
frames = []
y=[]

for counter, x in enumerate(clean_teamlist):
    try:
        globals()["df"+str(counter)] = get_roster(x,2020)
        frames.append(globals()["df"+str(counter)])
        y.append(str(x))
    except:
        pass

results = pd.concat(frames)
results
# Out:
#    NUMBER              PLAYER POS HEIGHT  WEIGHT BIRTH_DATE NATIONALITY  \
# 0      95     DeAndre' Bembry  SG    6-5     210 1994-07-04          US
# 1       4       Charlie Brown  SG    6-6     199 1997-02-02          US
# 2      15        Vince Carter  PF    6-6     220 1977-01-26          US
# 3      20        John Collins  PF    6-9     235 1997-09-23          US
# 4      33        Allen Crabbe  SG    6-5     212 1992-04-09          US
# ..    ...                 ...  ..    ...     ...        ...         ...
# 18     14           Ish Smith  PG    6-0     175 1988-07-05          US
# 19      4       Isaiah Thomas  PG    5-9     185 1989-02-07          US
# 20      7       Jarrod Uthoff  PF    6-9     221 1993-05-19          US
# 21     21       Moritz Wagner   C   6-11     245 1997-04-26          DE
# 22     19  Johnathan Williams  PF    6-9     228 1995-05-22          US
#
#    EXPERIENCE            COLLEGE
# 0           3     Saint Joseph's
# 1           R     Saint Joseph's
# ...

# %%
df_name = ['df1', 'df2', 'df3', 'df4', 'df5', 'df6', 'df7', 'df8', 'df9', 'df10', 
           'df11', 'df12', 'df13', 'df14', 'df15', 'df16', 'df17', 'df18', 'df19', 'df20',
          'df21', 'df22', 'df23', 'df24', 'df25', 'df26', 'df27', 'df28', 'df29', 'df30']

# %%
#frame = []
df = pd.DataFrame()

for t in clean_teamlist:
        try:
            df = get_roster(t,2020)
            result = pd.concat(df, keys=t)
        except:
            pass
df

# result = pd.concat(df_name, keys=clean_teamlist)
# result
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_name

# %%
frames = [df,df1]
teamlist = ['ATL','MIL']
result = pd.concat(frames, keys=teamlist)
result

# %%
get_roster(ATL,2020)

# %%
result = pd.concat(frames, keys=clean_teamlist)

# %%
df= get_roster('ATL',2020)
# Out:
#     NUMBER            PLAYER POS HEIGHT  WEIGHT BIRTH_DATE NATIONALITY  \
# 0       95   DeAndre' Bembry  SG    6-5     210 1994-07-04          US
# 1        4     Charlie Brown  SG    6-6     199 1997-02-02          US
# 2       15      Vince Carter  PF    6-6     220 1977-01-26          US
# 3       20      John Collins  PF    6-9     235 1997-09-23          US
# 4       33      Allen Crabbe  SG    6-5     212 1992-04-09          US
# 5       14    Dewayne Dedmon   C    7-0     245 1989-08-12          US
# 6       24    Bruno Fernando   C    6-9     240 1998-08-15          AO
# 7        0   Brandon Goodwin  PG    6-0     180 1995-10-02          US
# 8        2    Treveon Graham  SF    6-5     219 1993-10-28          US
# 9        3     Kevin Huerter  SG    6-7     190 1998-08-27          US
# 10      12   De'Andre Hunter  SF    6-7     225 1997-12-02          US
# 11      30      Damian Jones   C   6-11     245 1995-06-30          US
# ...

# %%
df1=get_roster(teamlist,2020)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-777f6d8915e0> in <module>
# ----> 1 df1=get_roster(teamlist,2020)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/basketball_reference_scraper/teams.py in get_roster(team, season_end_year)
#      14         soup = BeautifulSoup(r.content, 'html.parser')
#      15         table = soup.find('table')
# ---> 16         df = pd.read_html(str(table))[0]
#      17         df.columns = ['NUMBER', 'PLAYER', 'POS', 'HEIGHT', 'WEIGHT', 'BIRTH_DATE',
#      18                         'NATIONALITY', 'EXPERIENCE', 'COLLEGE']
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1103         na_values=na_values,
# ...

# %%
frames = [df,df1]
teamlist = ['ATL','MIL']
result = pd.concat(frames, keys=clean_teamlist)
result
# Out:
#            NUMBER               PLAYER POS HEIGHT  WEIGHT BIRTH_DATE  \
# NUMBER 0        3         Bradley Beal  SG    6-3     207 1993-06-28
#        1       42      DÄvis BertÄns  PF   6-10     225 1992-11-12
#        2       17          Isaac Bonga  SF    6-8     180 1999-11-08
#        3        6           Troy Brown  SF    6-6     215 1999-07-28
#        4       13        Thomas Bryant   C   6-10     248 1997-07-31
#        5        9        Chris Chiozza  PG   5-11     175 1995-11-21
#        6       22         Jerian Grant  SG    6-4     205 1992-10-09
#        7        8        Rui Hachimura  PF    6-8     230 1998-02-08
#        8       28          Ian Mahinmi   C   6-11     262 1986-11-05
#        9       24     Garrison Mathews  SG    6-5     215 1996-10-24
#        10      52         Jordan McRae  SG    6-5     179 1991-03-28
#        11      34           C.J. Miles  SF    6-6     220 1987-03-18
#        12       5       Shabazz Napier  PG    6-0     175 1991-07-14
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-2eb24d792d5d> in <module>
# ----> 1 print(ATL)
#
# NameError: name 'ATL' is not defined

# %%
clean_teamlist
# Out:
# ['NUMBER',
#  'PLAYER',
#  'POS',
#  'HEIGHT',
#  'WEIGHT',
#  'BIRTH_DATE',
#  'NATIONALITY',
#  'EXPERIENCE',
#  'COLLEGE']

# %%
teamlist
# Out:
# ['ATL', 'MIL']

# %%
# Out:
#             NUMBER           PLAYER POS HEIGHT  WEIGHT BIRTH_DATE NATIONALITY  \
# NUMBER  0       95  DeAndre' Bembry  SG    6-5     210 1994-07-04          US
#         1        4    Charlie Brown  SG    6-6     199 1997-02-02          US
#         2       15     Vince Carter  PF    6-6     220 1977-01-26          US
#         3       20     John Collins  PF    6-9     235 1997-09-23          US
#         4       33     Allen Crabbe  SG    6-5     212 1992-04-09          US
# ...            ...              ...  ..    ...     ...        ...         ...
# COLLEGE 16       0      Jeff Teague  PG    6-3     195 1988-06-10          US
#         17       1      Evan Turner  SG    6-6     220 1988-10-27          US
#         18       8   Tyrone Wallace  SG    6-5     198 1994-06-10          US
#         19       2      Paul Watson  SF    6-7     215 1994-12-30          US
#         20      11       Trae Young  PG    6-1     180 1998-09-19          US
#
# ...
