# %%
import pandas as pd
import os

# %%
data = pd.read_csv('../Extract/Resources/NBA_Season_Data.csv')

# %%
df_clean = data.dropna(axis=1, how='any')

# %%
df_clean
# Out:
#        Year   Tm              Player  Age  G  MP    PER   ORB%  DRB%  TRB%  \
# 0      1999  NJN    Gheorghe Muresan   27  1   1  -90.6    0.0   0.0   0.0
# 1      2016  IND  Shayne Whittington   24  1   2  -64.6    0.0   0.0   0.0
# 2      1979  DET         Ron Behagen   28  1   1  -60.3    0.0   0.0   0.0
# 3      2001  CLE      Larry Robinson   33  1   1  -54.4    0.0   0.0   0.0
# 4      2006  DEN        Nene Hilario   23  1   3  -54.4    0.0   0.0   0.0
# ...     ...  ...                 ...  ... ..  ..    ...    ...   ...   ...
# 17258  1991  PHO        Ian Lockhart   23  1   2   76.3    0.0   0.0   0.0
# 17259  2008  HOU        Gerald Green   22  1   4   76.3   57.3   0.0  28.2
# 17260  2009  OKC         Steven Hill   23  1   2   88.3  100.0  58.6  86.4
# 17261  2005  NYK       Jackie Butler   19  3   5   90.3    0.0   0.0   0.0
# 17262  2014  MIA     DeAndre Liggins   25  1   1  129.1  100.0   0.0  62.8
#
#        AST%  STL%  BLK%  USG%
# 0       0.0   0.0   0.0  88.3
# ...

# %%
df_clean.to_csv(r'season_small.csv')
