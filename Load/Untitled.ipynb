# %%
import pymongo
import pandas as pd
import json
from sqlalchemy import create_engine

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
db = client['Project']
collection = db['Player_info']

# %%
pStats = pd.read_csv('../Transform/clean_data/Player_Info.csv')
pStats
# Out:
#      Unnamed: 0              PLAYER POS HEIGHT  WEIGHT    BIRTH_DATE  \
# 0             0     DeAndre' Bembry  SG    6-5     210  773280000000
# 1             1       Charlie Brown  SG    6-6     199  854841600000
# 2             2        Vince Carter  PF    6-6     220  223084800000
# 3             3        John Collins  PF    6-9     235  874972800000
# 4             4      Bruno Fernando   C    6-9     240  903139200000
# ..          ...                 ...  ..    ...     ...           ...
# 525         525           Ish Smith  PG    6-0     175  584064000000
# 526         526       Isaiah Thomas  PG    5-9     185  602812800000
# 527         527       Jarrod Uthoff  PF    6-9     221  737769600000
# 528         528       Moritz Wagner   C   6-11     245  862012800000
# 529         529  Johnathan Williams  PF    6-9     228  801100800000
#
#     NATIONALITY EXPERIENCE            COLLEGE
# 0            US          3     Saint Joseph's
# ...

# %%
player_info_dict = pStats.to_dict("Players")
collection.insert_many(player_info_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-21bbf35f69bb> in <module>
# ----> 1 player_info_dict = pStats.to_dict("Players")
#       2 collection.insert_many(player_info_dict)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in to_dict(self, orient, into)
#    1395             )
#    1396         else:
# -> 1397             raise ValueError("orient '{o}' not understood".format(o=orient))
#    1398
#    1399     def to_gbq(
#
# ValueError: orient 'Players' not understood

# %%
connection_string = "postgres:postgres@localhost:5432/PROJECT2_ETL"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ...
